# %% [markdown]
# <a href="https://colab.research.google.com/github/rahul456833/GuviMLproj/blob/main/Copy_of_Copper_Modeling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
from datetime import datetime, timedelta
from sklearn.preprocessing import OrdinalEncoder
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **Load the Dataset**

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab/Copper_Set.csv", encoding='latin1')  # or 'ISO-8859-1', 'cp1252'
df
# Out:
#                                           id   item_date quantity tons  \
# 0       EC06F063-9DF0-440C-8764-0B0C05A4F6AE  20210401.0     54.151139
# 1       4E5F4B3D-DDDF-499D-AFDE-A3227EC49425  20210401.0    768.024839
# 2       E140FF1B-2407-4C02-A0DD-780A093B1158  20210401.0    386.127949
# 3       F8D507A0-9C62-4EFE-831E-33E1DA53BB50  20210401.0    202.411065
# 4       4E1C4E78-152B-430A-8094-ADD889C9D0AD  20210401.0    785.526262
# ...                                      ...         ...           ...
# 181668  DE633116-D1DF-4846-982E-55EFC3658A76  20200702.0   102.4824216
# 181669  A48374B1-E6DB-45F2-889A-1F9C27C099EB  20200702.0   208.0864686
# 181670  91643238-5C7B-4237-9A5F-63AE3D35F320  20200702.0   4.235593568
# 181671  7AFFD323-01D9-4E15-B80D-7D1B03498FC8  20200702.0         -2000
# 181672  AD0CA853-AE3C-4B2F-9FBB-8B0B965F84BC  20200702.0   406.6865384
#
#           customer  country status item type  application  thickness   width  \
# ...

# %%
for i in list(df.columns):
    print(f"{i}:{df[i].nunique()}")
    df.dtypes
# Out:
# id:181671
# item_date:252
# quantity tons:181673
# customer:1169
# country:17
# status:9
# item type:7
# application:30
# thickness:594
# width:1386
# material_ref:16563
# product_ref:33
# delivery date:28
# selling_price:9795

# %%
df['quantity tons'] = pd.to_numeric(df['quantity tons'], errors='coerce')
df['item_date_1'] = pd.to_datetime(df['item_date'], format='%Y%m%d', errors='coerce').dt.date
df['delivery date_1'] = pd.to_datetime(df['delivery date'], format='%Y%m%d', errors='coerce').dt.date
df.head(3)
df.isnull().sum()
# Out:
# id                     2
# item_date              1
# quantity tons          1
# customer               1
# country               28
# status                 2
# item type              0
# application           24
# thickness              1
# width                  0
# material_ref       77919
# product_ref            0
# delivery date          1
# selling_price          1
# item_date_1            3
# delivery date_1        3
# dtype: int64

# %%
df['material_ref'] = df['material_ref'].apply(lambda x: np.nan if str(x).startswith('00000') else x)
df.head(3)
df.isnull().sum()
# Out:
# id                      2
# item_date               1
# quantity tons           1
# customer                1
# country                28
# status                  2
# item type               0
# application            24
# thickness               1
# width                   0
# material_ref       100645
# product_ref             0
# delivery date           1
# selling_price           1
# item_date_1             3
# delivery date_1         3
# dtype: int64

# %%
df.drop(columns=['id','material_ref'], inplace=True)
df
df.describe().T
# Out:
#                   count          mean           std          min  \
# item_date      181672.0  2.020459e+07  4.551119e+03  19950000.00
# quantity tons  181672.0  5.874926e+03  2.349081e+06     -2000.00
# customer       181672.0  3.051221e+07  2.433382e+07     12458.00
# country        181645.0  4.489302e+01  2.440421e+01        25.00
# application    181649.0  2.561581e+01  1.775417e+01         2.00
# thickness      181672.0  2.564827e+00  6.572321e+00         0.18
# width          181673.0  1.295287e+03  2.616318e+02         1.00
# product_ref    181673.0  4.739679e+08  7.175101e+08    611728.00
# delivery date  181672.0  2.020738e+07  2.411059e+04  20190401.00
# selling_price  181672.0  1.918036e+03  3.317956e+05     -1160.00
#
#                         25%           50%           75%           max
# item_date      2.020093e+07  2.020113e+07  2.021020e+07  2.021040e+07
# quantity tons  1.097030e+01  3.036464e+01  6.716061e+01  1.000000e+09
# ...

# %%
df['quantity tons'] = df['quantity tons'].apply(lambda x: np.nan if x<=0 else x)
df['selling_price'] = df['selling_price'].apply(lambda x: np.nan if x<=0 else x)
df.describe().T
df.isnull().sum()
# Out:
# item_date           1
# quantity tons       5
# customer            1
# country            28
# status              2
# item type           0
# application        24
# thickness           1
# width               0
# product_ref         0
# delivery date       1
# selling_price       8
# item_date_1         3
# delivery date_1     3
# dtype: int64

# %%
df['item_date'].fillna(df['item_date'].mode().iloc[0], inplace=True)
df['item_date_1'].fillna(df['item_date_1'].mode().iloc[0], inplace=True)
df['status'].fillna(df['status'].mode().iloc[0], inplace=True)
df['delivery date'].fillna(df['delivery date'].mode().iloc[0], inplace=True)
df['delivery date_1'].fillna(df['delivery date_1'].mode().iloc[0], inplace=True)

# %%
df['quantity tons'].fillna(df['quantity tons'].median(), inplace=True)
df['customer'].fillna(df['customer'].median(), inplace=True)
df['country'].fillna(df['country'].median(), inplace=True)
df['application'].fillna(df['application'].median(), inplace=True)
df['thickness'].fillna(df['thickness'].median(), inplace=True)
df['selling_price'].fillna(df['selling_price'].median(), inplace=True)

# %%
df.isnull().sum()
df['status'].unique()
df['item type'].unique()
# Out:
# array(['W', 'WI', 'S', 'Others', 'PL', 'IPL', 'SLAWR'], dtype=object)

# %%
df['status'] = df['status'].map({'Lost':0, 'Won':1, 'Draft':2, 'To be approved':3, 'Not lost for AM':4, 'Wonderful':5, 'Revised':6, 'Offered':7, 'Offerable':8})
df['item type'] = OrdinalEncoder().fit_transform(df[['item type']])
df
# Out:
#          item_date  quantity tons    customer  country  status  item type  \
# 0       20210401.0      54.151139  30156308.0     28.0       1        5.0
# 1       20210401.0     768.024839  30202938.0     25.0       1        5.0
# 2       20210401.0     386.127949  30153963.0     30.0       1        6.0
# 3       20210401.0     202.411065  30349574.0     32.0       1        3.0
# 4       20210401.0     785.526262  30211560.0     28.0       1        5.0
# ...            ...            ...         ...      ...     ...        ...
# 181668  20200702.0     102.482422  30200854.0     25.0       1        5.0
# 181669  20200702.0     208.086469  30200854.0     25.0       1        5.0
# 181670  20200702.0       4.235594  30200854.0     25.0       1        5.0
# 181671  20200702.0      30.365013  30200854.0     25.0       1        5.0
# 181672  20200702.0     406.686538  30200854.0     25.0       1        5.0
#
#         application  thickness   width  product_ref  delivery date  \
# ...

# %%
df['item type'].unique()
df.isnull().sum()
df.describe().T
# Out:
#                   count          mean           std           min  \
# item_date      181673.0  2.020459e+07  4.551114e+03  1.995000e+07
# quantity tons  181673.0  5.874905e+03  2.349075e+06  1.000000e-05
# customer       181673.0  3.051221e+07  2.433375e+07  1.245800e+04
# country        181673.0  4.489073e+01  2.440303e+01  2.500000e+01
# status         181673.0  1.316684e+00  1.330310e+00  0.000000e+00
# item type      181673.0  4.133036e+00  1.055230e+00  0.000000e+00
# application    181673.0  2.561441e+01  1.775342e+01  2.000000e+00
# thickness      181673.0  2.564822e+00  6.572303e+00  1.800000e-01
# width          181673.0  1.295287e+03  2.616318e+02  1.000000e+00
# product_ref    181673.0  4.739679e+08  7.175101e+08  6.117280e+05
# delivery date  181673.0  2.020738e+07  2.411052e+04  2.019040e+07
# selling_price  181673.0  1.918076e+03  3.317947e+05  1.000000e-01
#
#                         25%           50%           75%           max
# ...

# %%
def plots(df, column):
    plt.figure(figsize=(20,5))
    plt.subplot(1,3,1)
    sns.boxplot(data=df, x=column)
    plt.title(f'Box Plot for {column}')

    plt.subplot(1,3,2)
    sns.histplot(data=df, x=column, kde=True, bins=50)
    plt.title(f'Distribution Plot for {column}')

    plt.subplot(1,3,3)
    sns.violinplot(data=df, x=column)
    plt.title(f'Violin Plot for {column}')
    plt.show()

# %%
for i in ['quantity tons', 'customer', 'country', 'item type', 'application', 'thickness', 'width', 'selling_price']:
    plots(df, i)

# %%
df1 = df.copy()
df1['quantity tons_log'] = np.log(df1['quantity tons'])
df1['thickness_log'] = np.log(df1['thickness'])
df1['selling_price_log'] = np.log(df1['selling_price'])
df1
# Out:
#          item_date  quantity tons    customer  country  status  item type  \
# 0       20210401.0      54.151139  30156308.0     28.0       1        5.0
# 1       20210401.0     768.024839  30202938.0     25.0       1        5.0
# 2       20210401.0     386.127949  30153963.0     30.0       1        6.0
# 3       20210401.0     202.411065  30349574.0     32.0       1        3.0
# 4       20210401.0     785.526262  30211560.0     28.0       1        5.0
# ...            ...            ...         ...      ...     ...        ...
# 181668  20200702.0     102.482422  30200854.0     25.0       1        5.0
# 181669  20200702.0     208.086469  30200854.0     25.0       1        5.0
# 181670  20200702.0       4.235594  30200854.0     25.0       1        5.0
# 181671  20200702.0      30.365013  30200854.0     25.0       1        5.0
# 181672  20200702.0     406.686538  30200854.0     25.0       1        5.0
#
#         application  thickness   width  product_ref  delivery date  \
# ...

# %%
for i in ['quantity tons_log', 'thickness_log', 'width', 'selling_price_log']:
    plots(df1, i)
df2 = df1.copy()
df2
# Out:
#          item_date  quantity tons    customer  country  status  item type  \
# 0       20210401.0      54.151139  30156308.0     28.0       1        5.0
# 1       20210401.0     768.024839  30202938.0     25.0       1        5.0
# 2       20210401.0     386.127949  30153963.0     30.0       1        6.0
# 3       20210401.0     202.411065  30349574.0     32.0       1        3.0
# 4       20210401.0     785.526262  30211560.0     28.0       1        5.0
# ...            ...            ...         ...      ...     ...        ...
# 181668  20200702.0     102.482422  30200854.0     25.0       1        5.0
# 181669  20200702.0     208.086469  30200854.0     25.0       1        5.0
# 181670  20200702.0       4.235594  30200854.0     25.0       1        5.0
# 181671  20200702.0      30.365013  30200854.0     25.0       1        5.0
# 181672  20200702.0     406.686538  30200854.0     25.0       1        5.0
#
#         application  thickness   width  product_ref  delivery date  \
# ...

# %%
def outliers(df, column):
    iqr = df[column].quantile(0.75) - df[column].quantile(0.25)
    upper_threshold = df[column].quantile(0.75) + (1.5*iqr)
    lower_threshold = df[column].quantile(0.25) - (1.5*iqr)
    df[column] = df[column].clip(lower_threshold, upper_threshold)

# %%
outliers(df2, 'quantity tons_log')
outliers(df2, 'thickness_log')
outliers(df2, 'selling_price_log')
outliers(df2, 'width')
df2
# Out:
#          item_date  quantity tons    customer  country  status  item type  \
# 0       20210401.0      54.151139  30156308.0     28.0       1        5.0
# 1       20210401.0     768.024839  30202938.0     25.0       1        5.0
# 2       20210401.0     386.127949  30153963.0     30.0       1        6.0
# 3       20210401.0     202.411065  30349574.0     32.0       1        3.0
# 4       20210401.0     785.526262  30211560.0     28.0       1        5.0
# ...            ...            ...         ...      ...     ...        ...
# 181668  20200702.0     102.482422  30200854.0     25.0       1        5.0
# 181669  20200702.0     208.086469  30200854.0     25.0       1        5.0
# 181670  20200702.0       4.235594  30200854.0     25.0       1        5.0
# 181671  20200702.0      30.365013  30200854.0     25.0       1        5.0
# 181672  20200702.0     406.686538  30200854.0     25.0       1        5.0
#
#         application  thickness   width  product_ref  delivery date  \
# ...

# %%
for i in ['quantity tons_log', 'thickness_log', 'width', 'selling_price_log']:
    plots(df2, i)
df2.describe().T
# Out:
#                       count          mean           std           min  \
# item_date          181673.0  2.020459e+07  4.551114e+03  1.995000e+07
# quantity tons      181673.0  5.874905e+03  2.349075e+06  1.000000e-05
# customer           181673.0  3.051221e+07  2.433375e+07  1.245800e+04
# country            181673.0  4.489073e+01  2.440303e+01  2.500000e+01
# status             181673.0  1.316684e+00  1.330310e+00  0.000000e+00
# item type          181673.0  4.133036e+00  1.055230e+00  0.000000e+00
# application        181673.0  2.561441e+01  1.775342e+01  2.000000e+00
# thickness          181673.0  2.564822e+00  6.572303e+00  1.800000e-01
# width              181673.0  1.297046e+03  2.489619e+02  7.000000e+02
# product_ref        181673.0  4.739679e+08  7.175101e+08  6.117280e+05
# delivery date      181673.0  2.020738e+07  2.411052e+04  2.019040e+07
# selling_price      181673.0  1.918076e+03  3.317947e+05  1.000000e-01
# ...

# %%
df3 = df2.drop(columns=['quantity tons', 'thickness', 'selling_price'])
df3
df3.dtypes
# Out:
# item_date            float64
# customer             float64
# country              float64
# status                 int64
# item type            float64
# application          float64
# width                float64
# product_ref            int64
# delivery date        float64
# item_date_1           object
# delivery date_1       object
# quantity tons_log    float64
# thickness_log        float64
# selling_price_log    float64
# dtype: object

# %%
col = ['quantity tons_log','customer','country','status','application','width','product_ref','thickness_log','selling_price_log']
df_corelation = df3[col].corr()
df4 = df3.copy()
df4
df_corelation
# Out:
#                    quantity tons_log  customer   country    status  \
# quantity tons_log           1.000000  0.002559 -0.090655  0.023800
# customer                    0.002559  1.000000 -0.006669  0.004775
# country                    -0.090655 -0.006669  1.000000 -0.028903
# status                      0.023800  0.004775 -0.028903  1.000000
# application                 0.066483 -0.006869 -0.019304  0.085808
# width                       0.032100  0.009585  0.053867 -0.053129
# product_ref                 0.064665 -0.007716 -0.147326 -0.008033
# thickness_log               0.041198  0.018860 -0.065362 -0.083867
# selling_price_log          -0.039051 -0.025967 -0.019936  0.032381
#
#                    application     width  product_ref  thickness_log  \
# quantity tons_log     0.066483  0.032100     0.064665       0.041198
# customer             -0.006869  0.009585    -0.007716       0.018860
# country              -0.019304  0.053867    -0.147326      -0.065362
# ...

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df_corelation.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix Heatmap')
plt.show()

for column in df_corelation.columns:
    plt.figure(figsize=(6, 4))
    sns.histplot(df_corelation[column], kde=True)
    plt.title(f'Distribution of {column}')
    plt.show()

for column in df_corelation.columns:
    plt.figure(figsize=(6, 4))
    sns.displot(x=column, data=df_corelation, kind='kde')

    plt.title(f'Distribution Plot of {column}')
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()

plt.figure(figsize=(6, 4))
sns.scatterplot(x='quantity tons_log', y='selling_price_log', data=df_corelation)
plt.title('Scatter Plot: Quantity vs. Selling Price')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = {
    'quantity_tons_log': np.random.rand(20),
    'customer': np.random.rand(20),
    'country': np.random.rand(20),
    'status': np.random.rand(20),
    'application': np.random.rand(20),
    'selling_price': np.random.rand(20),
    'thickness': np.random.rand(20),
    'width': np.random.rand(20),
}
df_plot = pd.DataFrame(data)

# Create the plots with 2 rows and 4 columns
fig, axes = plt.subplots(2, 4, figsize=(20, 8))  # Changed to 2 rows, 4 columns
fig.subplots_adjust(hspace=0.4, wspace=0.4)

# Plot 1: Histogram of 'quantity_tons_log'
axes[0, 0].hist(df_plot['quantity_tons_log'], bins=10, color='lightgreen', alpha=0.7)
axes[0, 0].set_title("quantity tons_log")

# Plot 2: Histogram of 'customer'
axes[0, 1].hist(df_plot['customer'], bins=10, color='lightgreen', alpha=0.7)
axes[0, 1].set_title("customer")

# Plot 3: Histogram of 'country'
axes[0, 2].hist(df_plot['country'], bins=10, color='lightgreen', alpha=0.7)
axes[0, 2].set_title("country")

# Plot 4: Histogram of 'status'
axes[0, 3].hist(df_plot['status'], bins=10, color='lightgreen', alpha=0.7)
axes[0, 3].set_title("status")

# Plot 5: Scatter plot of 'quantity_tons_log' vs 'customer'
axes[1, 0].scatter(df_plot['quantity_tons_log'], df_plot['customer'], color='lightgreen')
axes[1, 0].set_title("quantity tons_log vs customer")

# Plot 6: Scatter plot of 'customer' vs 'country'
axes[1, 1].scatter(df_plot['customer'], df_plot['country'], color='lightgreen')
axes[1, 1].set_title("customer vs country")

# Plot 7: Scatter plot of 'selling_price' vs 'quantity_tons_log'
axes[1, 2].scatter(df_plot['selling_price'], df_plot['quantity_tons_log'], color='lightgreen')
axes[1, 2].set_title("Selling Price vs Quantity Tons")

# Plot 8: Scatter plot of 'country' vs 'status'
axes[1, 3].scatter(df_plot['country'], df_plot['status'], color='lightgreen')
axes[1, 3].set_title("country vs status")

plt.show()

# %%
df4['Date_difference'] = (df4['delivery date_1'] - df4['item_date_1']).apply(lambda x: x.days)
df4.head()
# Out:
#     item_date    customer  country  status  item type  application   width  \
# 0  20210401.0  30156308.0     28.0       1        5.0         10.0  1500.0
# 1  20210401.0  30202938.0     25.0       1        5.0         41.0  1210.0
# 2  20210401.0  30153963.0     30.0       1        6.0         28.0   952.0
# 3  20210401.0  30349574.0     32.0       1        3.0         59.0  1317.0
# 4  20210401.0  30211560.0     28.0       1        5.0         10.0  1980.0
#
#    product_ref  delivery date item_date_1 delivery date_1  quantity tons_log  \
# 0   1670798778     20210701.0  2021-04-01      2021-07-01           3.991779
# 1   1668701718     20210401.0  2021-04-01      2021-04-01           6.643822
# 2       628377     20210101.0  2021-04-01      2021-01-01           5.956169
# 3   1668701718     20210101.0  2021-04-01      2021-01-01           5.310301
# 4       640665     20210301.0  2021-04-01      2021-03-01           6.666354
#
# ...

# %%
df4['item_date_1'] = pd.to_datetime(df4['item_date_1'])
df4['item_date_day'] = df4['item_date_1'].dt.day
df4['item_date_month'] = df4['item_date_1'].dt.month
df4['item_date_year'] = df4['item_date_1'].dt.year
df4
# Out:
#          item_date    customer  country  status  item type  application  \
# 0       20210401.0  30156308.0     28.0       1        5.0         10.0
# 1       20210401.0  30202938.0     25.0       1        5.0         41.0
# 2       20210401.0  30153963.0     30.0       1        6.0         28.0
# 3       20210401.0  30349574.0     32.0       1        3.0         59.0
# 4       20210401.0  30211560.0     28.0       1        5.0         10.0
# ...            ...         ...      ...     ...        ...          ...
# 181668  20200702.0  30200854.0     25.0       1        5.0         41.0
# 181669  20200702.0  30200854.0     25.0       1        5.0         41.0
# 181670  20200702.0  30200854.0     25.0       1        5.0         41.0
# 181671  20200702.0  30200854.0     25.0       1        5.0         41.0
# 181672  20200702.0  30200854.0     25.0       1        5.0         41.0
#
#          width  product_ref  delivery date item_date_1 delivery date_1  \
# ...

# %%
df_f1 = df4[df4['Date_difference']>=0]
df_f1 = df_f1.reset_index(drop=True)
df_f1
df_f2 = df4[df4['Date_difference']<0]
df_f2 = df_f2.reset_index(drop=True)
df_f2
# Out:
#         item_date    customer  country  status  item type  application  \
# 0      20210401.0  30153963.0     30.0       1        6.0         28.0
# 1      20210401.0  30349574.0     32.0       1        3.0         59.0
# 2      20210401.0  30211560.0     28.0       1        5.0         10.0
# 3      20210401.0  30342192.0     32.0       1        5.0         41.0
# 4      20210401.0  30342192.0     32.0       1        5.0         41.0
# ...           ...         ...      ...     ...        ...          ...
# 16103  20200702.0  30200854.0     25.0       1        5.0         41.0
# 16104  20200702.0  30200854.0     25.0       1        5.0         41.0
# 16105  20200702.0  30200854.0     25.0       1        5.0         41.0
# 16106  20200702.0  30200854.0     25.0       1        5.0         41.0
# 16107  20200702.0  30200854.0     25.0       1        5.0         41.0
#
#         width  product_ref  delivery date item_date_1 delivery date_1  \
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
df_f1.columns
# Out:
# Index(['item_date', 'customer', 'country', 'status', 'item type',
#        'application', 'width', 'product_ref', 'delivery date', 'item_date_1',
#        'delivery date_1', 'quantity tons_log', 'thickness_log',
#        'selling_price_log', 'Date_difference', 'item_date_day',
#        'item_date_month', 'item_date_year'],
#       dtype='object')

# %%
def machine_learning_delivery_date(df, algorithm):

    x = df.drop(columns=['item_date_1', 'delivery date_1', 'Date_difference'], axis=1)
    y = df['Date_difference']

    from sklearn.impute import SimpleImputer
    imputer = SimpleImputer(strategy='median')
    x = imputer.fit_transform(x)
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

    model = algorithm().fit(x_train, y_train)
    y_pred = model.predict(x_test)

    mse = mean_squared_error(y_test, y_pred)
    rmse = np.sqrt(mse)
    r2 = r2_score(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)

    metrics = {'Algorithm': str(algorithm).split("'")[1].split(".")[-1],
               'R2': r2,
               'Mean Absolute Error': mae,
               'Mean Squared Error': mse,
               'Root Mean Squared Error': rmse}

    return metrics

# %%
print(machine_learning_delivery_date(df_f1, DecisionTreeRegressor))
print(machine_learning_delivery_date(df_f1, RandomForestRegressor))
print(machine_learning_delivery_date(df_f1, AdaBoostRegressor))
print(machine_learning_delivery_date(df_f1, XGBRegressor))
# Out:
# {'Algorithm': 'DecisionTreeRegressor', 'R2': 0.99709766659316, 'Mean Absolute Error': 0.01796877359345272, 'Mean Squared Error': 4.459728807417027, 'Root Mean Squared Error': 2.111807000513311}
# {'Algorithm': 'RandomForestRegressor', 'R2': 0.999925400871174, 'Mean Absolute Error': 0.008384924349953193, 'Mean Squared Error': 0.11619512276145322, 'Root Mean Squared Error': 0.3408740570378644}
# {'Algorithm': 'AdaBoostRegressor', 'R2': 0.7351188435699794, 'Mean Absolute Error': 16.85113999547511, 'Mean Squared Error': 410.7976286211309, 'Root Mean Squared Error': 20.26814319618674}
# {'Algorithm': 'XGBRegressor', 'R2': 0.9999327659606934, 'Mean Absolute Error': 0.18309967907022034, 'Mean Squared Error': 0.10376585097794684, 'Root Mean Squared Error': 0.3221270727181229}

# %%
def machine_learning_delivery_date(df, algorithm):
  model = RandomForestRegressor().fit(
      df_f1.drop(columns=['item_date_1', 'delivery date_1', 'Date_difference'], axis=1),
      df_f1['Date_difference']
  )
  return model # Return the trained model

model = machine_learning_delivery_date(df_f1, RandomForestRegressor)  # Assign the returned model to a variable

user_data = np.array([[30153963, 30, 6, 28, 952, 628377, 5.9, -0.96, 6.46, 1, 4, 2021, 1, 1, 2021]])
y_p = model.predict(user_data) # Now 'model' is defined and accessible
if y_p[0] == 1:
    print('Won')
else:
    print('Lose')
